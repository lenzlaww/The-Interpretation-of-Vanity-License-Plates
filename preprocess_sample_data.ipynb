# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd /gdrive/MyDrive/Colab Notebooks/CSE519/Project
# !ls
# Out:
# /gdrive/MyDrive/Colab Notebooks/CSE519/Project
# preprocess_sample_data.ipynb  sample_data_new.csv     sampled_data.csv
# sample_data_analysis.csv      sample_data_new.gsheet

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from scipy.stats import multivariate_normal
import json
import re

# %% [markdown]
# # Load data

# %%
sample_data = pd.read_csv('sampled_data.csv')
sample_data.head(10)
# Out:
#      plate review_reason_code  \
# 0  DEZERTG                  2
# 1  TAY HOE                  1
# 2  1TRMN8R                  2
# 3  WTFUWNT                  3
# 4  CPT1964                  2
# 5  F32 BMR                  2
# 6   DKHRS2                  1
# 7  ESE RIX                NaN
# 8  24SF415                  2
# 9    8BMJ8                  2
#
#                                     customer_meaning  \
# 0       MY LOVE FOR THE DESERT AND MY MIDDLE INITIAL
# 1  OUR VEHICLE IS A CHEVY TAHOE, AND OUR 2 YEAR O...
# 2                                NICKNAME FOR MY CAR
# 3             PERSONAL MANTRA-WAIT FOR WHAT YOU WANT
# 4                       THE ORIGINAL YEAR OF THE CAR
# 5  F32 IS THE VHASSIS CODE FOR THIS VEHICLE BMR I...
# 6                                                NaN
# 7                                       THAT'S RICKS
# 8                                      SAN FRANCISCO
# 9                FAVORITE NUMBER AND FAMILY INITIALS
#
#                                    reviewer_comments status  \
# 0                                  G, GANG REFERENCE      Y
# 1       Says "HO", has a Chevy UT. Could be a Tahoe.      N
# 2             TERMINATOR COULD BE CONSIDERED HOSTILE      N
# 3                             WHAT THE FUCK YOU WANT      N
# 4  CPT CAN STAND FOR COLORED PEOPLE'S TIME, RACIS...      N
# 5                                         F32 BOMBER      N
# 6                        COULD LOOK LIKE DICK WHORES      Y
# 7                          ESSAY RICK GANG REFERENCE      Y
# 8                                      415 AREA CODE      N
# 9                                 88, GANG REFERENCE      N
#
#                                             classify  \
# 0  ```json\n{\n  "personalized": "Y",\n  "valid":...
# 1  ```json\n{\n  "personalized": "Y",\n  "valid":...
# 2  ```json\n{\n  "personalized": "Y",\n  "valid":...
# 3  ```json\n{\n  "personalized": "Y",\n  "valid":...
# 4  ```json\n{\n  "personalized": "Y",\n  "valid":...
# 5  ```json\n{\n  "personalized": "Y",\n  "valid":...
# 6  ```json\n{\n  "personalized": "Y",\n  "valid":...
# 7  ```json\n{\n  "personalized": "Y",\n  "valid":...
# 8  ```json\n{\n  "personalized": "Y",\n  "valid":...
# 9  ```json\n{\n  "personalized": "Y",\n  "valid":...
#
#                                            interpret
# 0  The license plate "DEZERTG" could be interpret...
# 1  The license plate "TAY HOE" could be interpret...
# 2  The license plate "1TRMN8R" could be interpret...
# 3  WTFUWNT might be an acronym or a series of ini...
# 4  The plate "CPT1964" likely belongs to someone ...
# 5  The license plate "F32 BMR" could be interpret...
# 6  DKHRS2\n\nOutput: "This license plate could re...
# 7  "ESE RIX" could be interpreted as a playful or...
# 8  The plate "24SF415" appears to be a combinatio...
# 9  The plate "8BMJ8" could be interpreted as a pl...

# %% [markdown]
# # Extract info from 'classify'

# %%
first_row_classify_value = sample_data.iloc[0]['classify']
print(sample_data.iloc[0]['classify'])
print(sample_data.iloc[0]['interpret'])
# Out:
# ```json
# {
#   "personalized": "Y",
#   "valid": "Y",
#   "explanation": "The plate 'DEZERTG' is personalized as it does not follow the standard format for standard license plates which usually consist of a series of numbers and letters, and this plate contains a mix of letters and a word-like sequence."
# }
# ```
# The license plate "DEZERTG" could be interpreted as a play on the word "desert" with the last letter "G" possibly standing for "gang" or a person's name. This might suggest that the owner of the plate has a humorous or playful attitude about being in a "desert" gang, or is making a reference to a group or club named "Desert G."

# %%
sample_data['classify']
# Out:
# 0     ```json\n{\n  "personalized": "Y",\n  "valid":...
# 1     ```json\n{\n  "personalized": "Y",\n  "valid":...
# 2     ```json\n{\n  "personalized": "Y",\n  "valid":...
# 3     ```json\n{\n  "personalized": "Y",\n  "valid":...
# 4     ```json\n{\n  "personalized": "Y",\n  "valid":...
#                             ...
# 95    ```json\n{\n  "personalized": "Y",\n  "valid":...
# 96    ```json\n{\n  "personalized": "Y",\n  "valid":...
# 97    ```json\n{\n  "personalized": "Y",\n  "valid":...
# 98    ```json\n{\n  "personalized": "Y",\n  "valid":...
# 99    ```json\n{\n  "personalized": "Y",\n  "valid":...
# Name: classify, Length: 100, dtype: object

# %%
def clean_and_load_json(json_str):
    # Remove backticks and newlines, then strip extra whitespace
    json_str = re.sub(r'```|\n', '', json_str).strip()
    json_str = json_str[4:]
    try:
        # Convert cleaned string to dictionary
        return json.loads(json_str)
    except json.JSONDecodeError:
        # Handle any decoding errors (optional logging or handling)
        return None

# %%
clean_and_load_json(sample_data.iloc[0]['classify'])
# Out:
# {'personalized': 'Y',
#  'valid': 'Y',
#  'explanation': "The plate 'DEZERTG' is personalized as it does not follow the standard format for standard license plates which usually consist of a series of numbers and letters, and this plate contains a mix of letters and a word-like sequence."}

# %%
sample_data['classify'] = sample_data['classify'].apply(clean_and_load_json)

# Expand 'classify' column into separate columns
sample_data = pd.concat([sample_data.drop(columns=['classify']), sample_data['classify'].apply(pd.Series)], axis=1)
new_column_order = [
    'plate', 'review_reason_code', 'status', 'valid', 'customer_meaning',
    'reviewer_comments', 'interpret', 'personalized', 'explanation'
]
sample_data = sample_data[new_column_order]
sample_data.head(10)
# Out:
#      plate review_reason_code status valid  \
# 0  DEZERTG                  2      Y     Y
# 1  TAY HOE                  1      N     Y
# 2  1TRMN8R                  2      N     Y
# 3  WTFUWNT                  3      N     Y
# 4  CPT1964                  2      N     Y
# 5  F32 BMR                  2      N     Y
# 6   DKHRS2                  1      Y     Y
# 7  ESE RIX                NaN      Y     Y
# 8  24SF415                  2      N     Y
# 9    8BMJ8                  2      N     Y
#
#                                     customer_meaning  \
# 0       MY LOVE FOR THE DESERT AND MY MIDDLE INITIAL
# 1  OUR VEHICLE IS A CHEVY TAHOE, AND OUR 2 YEAR O...
# 2                                NICKNAME FOR MY CAR
# 3             PERSONAL MANTRA-WAIT FOR WHAT YOU WANT
# 4                       THE ORIGINAL YEAR OF THE CAR
# 5  F32 IS THE VHASSIS CODE FOR THIS VEHICLE BMR I...
# 6                                                NaN
# 7                                       THAT'S RICKS
# 8                                      SAN FRANCISCO
# 9                FAVORITE NUMBER AND FAMILY INITIALS
#
#                                    reviewer_comments  \
# 0                                  G, GANG REFERENCE
# 1       Says "HO", has a Chevy UT. Could be a Tahoe.
# 2             TERMINATOR COULD BE CONSIDERED HOSTILE
# 3                             WHAT THE FUCK YOU WANT
# 4  CPT CAN STAND FOR COLORED PEOPLE'S TIME, RACIS...
# 5                                         F32 BOMBER
# 6                        COULD LOOK LIKE DICK WHORES
# 7                          ESSAY RICK GANG REFERENCE
# 8                                      415 AREA CODE
# 9                                 88, GANG REFERENCE
#
#                                            interpret personalized  \
# 0  The license plate "DEZERTG" could be interpret...            Y
# 1  The license plate "TAY HOE" could be interpret...            Y
# 2  The license plate "1TRMN8R" could be interpret...            Y
# 3  WTFUWNT might be an acronym or a series of ini...            Y
# 4  The plate "CPT1964" likely belongs to someone ...            Y
# 5  The license plate "F32 BMR" could be interpret...            Y
# 6  DKHRS2\n\nOutput: "This license plate could re...            Y
# 7  "ESE RIX" could be interpreted as a playful or...            Y
# 8  The plate "24SF415" appears to be a combinatio...            Y
# 9  The plate "8BMJ8" could be interpreted as a pl...            Y
#
#                                          explanation
# 0  The plate 'DEZERTG' is personalized as it does...
# 1  The plate 'TAY HOE' contains non-standard lett...
# 2  The license plate '1TRMN8R' contains a combina...
# 3  The plate 'WTFUWNT' contains a sequence of let...
# 4  The plate 'CPT1964' is personalized as it does...
# 5  The license plate 'F32 BMR' contains a combina...
# 6  The plate 'DKHRS2' contains letters and number...
# 7  The plate 'ESE RIX' includes letters and numbe...
# 8  The plate is personalized as it contains non-s...
# 9  The plate '8BMJ8' is personalized as it does n...

# %%
sample_data.columns
# Out:
# Index(['plate', 'review_reason_code', 'status', 'valid', 'customer_meaning',
#        'reviewer_comments', 'interpret', 'personalized', 'explanation'],
#       dtype='object')

# %%
len(sample_data)
# Out:
# 100

# %%
unique_values = sample_data['personalized'].unique()
print(unique_values)
# Out:
# ['Y']

# %% [markdown]
# All plates are personalized.

# %% [markdown]
# # Analysis the result of LLM prediction

# %%
# compare with the LLM generated vaid with ground truth 'status'

filtered_df = sample_data[sample_data['valid'] == sample_data['status']]
len(filtered_df)
# Out:
# 18

# %%
filtered_df.head(18)
# Out:
#        plate review_reason_code status valid  \
# 0    DEZERTG                  2      Y     Y
# 6     DKHRS2                  1      Y     Y
# 7    ESE RIX                NaN      Y     Y
# 11  BAMMER 3                NaN      Y     Y
# 16  NEW BLUE                  2      Y     Y
# 19   RED KLK                  2      Y     Y
# 21   AYOO5OH                  5      Y     Y
# 26   REDFLAG                  2      Y     Y
# 35   NOSTOOL                  2      N     N
# 56   DUBAGNT                 7D      Y     Y
# 64     OFOGY                  2      Y     Y
# 66   HOMBOYS                  2      Y     Y
# 69     COORS                 7D      Y     Y
# 73     LUVIN                  1      Y     Y
# 78  JUNIOR C                  1      Y     Y
# 80   RED1TOY                  2      Y     Y
# 91    PNKSJP                  1      Y     Y
# 97     H1W4D                  2      Y     Y
#
#                                      customer_meaning  \
# 0        MY LOVE FOR THE DESERT AND MY MIDDLE INITIAL
# 6                                                 NaN
# 7                                        THAT'S RICKS
# 11                                                NaN
# 16                   OUR NEW CAR THAT'S BLUE IN COLOR
# 19                        RED KIMBERLY LILIANA KAMILA
# 21                                           CAR NAME
# 26  THE CAR IS RED, OLD AND FUNKY. IT STICKS OUT L...
# 35  ITS THE ABREVIATIONS FOR NITROUS OXIDE RACVE G...
# 56  I'M A WARRIOR FAN, NICKNAME THE DUBS. I'M  ALS...
# 64                                                NaN
# 66                                      CLOSE FRIENDS
# 69                              MY CHILDHOOD NICKNAME
# 73                                    I LOVE MY TRUCK
# 78  JUNIOR IS MY SON'S NAME AND THE  LETTER C IS F...
# 80  THE NAME OF MY COMPANY IS RED-TOY. SINCE THAT ...
# 91                                NOT ON QUICKWEB YET
# 97                        INITIAL MIXED WITH BIRTHDAY
#
#                                     reviewer_comments  \
# 0                                   G, GANG REFERENCE
# 6                         COULD LOOK LIKE DICK WHORES
# 7                           ESSAY RICK GANG REFERENCE
# 11  BAMMER ANOTHER NAMR FOR BAD WEED (BAMMER1 has ...
# 16                                               BLUE
# 19  RED=GANG COLOR, Customers name is Bolivar F Erazo
# 21                                       5OH = FIVE O
# 26                                     RED=GANG COLOR
# 35  STOOL IS ANOTHER WORD FOR SHIT LOOKS LIKE NO SHIT
# 56                                DUB, DRUG REFERENCE
# 64                               OG ORIGINAL GANGSTER
# 66                            COULD BE GANG REFERENCE
# 69                               BEER, INAPPROPRIATE?
# 73               LOVING.. COULD BE A SEXUAL REFERENCE
# 78                         THE C COULD STAND FOR COCK
# 80                                     RED=GANG COLOR
# 91  pulled for pink=pussy. Customer last name is P...
# 97                                  14 GANG REFERENCE
#
#                                             interpret personalized  \
# 0   The license plate "DEZERTG" could be interpret...            Y
# 6   DKHRS2\n\nOutput: "This license plate could re...            Y
# 7   "ESE RIX" could be interpreted as a playful or...            Y
# 11  The license plate "BAMMER 3" suggests that the...            Y
# 16  The license plate "NEW BLUE" suggests a sense ...            Y
# 19  The license plate "RED KLK" suggests a connect...            Y
# 21  The license plate "AYOO5OH" could be interpret...            Y
# 26  Output: "REDFLAG" could imply that the owner i...            Y
# 35  Output: The license plate "NOSTOOL" could be i...            Y
# 56  The license plate "DUBAGNT" could be interpret...            Y
# 64  The plate "OFOGY" could be interpreted as a pl...            Y
# 66  The license plate "HOMBOYS" likely signifies a...            Y
# 69  COORS could be interpreted as a nod to the fam...            Y
# 73  "LUVIN" suggests a positive sentiment, indicat...            Y
# 78  The license plate "JUNIOR C" might imply that ...            Y
# 80  The plate "RED1TOY" could be interpreted as a ...            Y
# 91  PNKSJP could be interpreted as a playful or ar...            Y
# 97  The license plate "H1W4D" could be interpreted...            Y
#
#                                           explanation
# 0   The plate 'DEZERTG' is personalized as it does...
# 6   The plate 'DKHRS2' contains letters and number...
# 7   The plate 'ESE RIX' includes letters and numbe...
# 11  The plate is personalized because it contains ...
# 16  The plate 'NEW BLUE' is personalized as it con...
# 19  The plate 'RED KLK' contains letters and numbe...
# 21  The plate 'AYOO5OH' is personalized because it...
# 26  The plate 'REDFLAG' is personalized because it...
# 35  The plate 'NOSTOOL' is personalized but invali...
# 56  The plate 'DUBAGNT' is personalized as it does...
# 64  The plate 'OFOGY' is personalized because it c...
# 66  The plate 'HOMBOYS' contains letters and words...
# 69  The license plate 'COORS' contains a brand nam...
# 73  The plate 'LUVIN' is personalized because it c...
# 78  The plate contains letters and numbers that do...
# 80  The plate contains a mix of alphanumeric chara...
# 91  The plate 'PNKSJP' contains characters that ar...
# 97  The plate 'H1W4D' contains a combination of le...

# %%
filtered_df
status_counts = filtered_df['status'].value_counts()
status_counts
# Out:
# status
# Y    17
# N     1
# Name: count, dtype: int64

# %%
valid_counts = sample_data['valid'].value_counts()
valid_counts
# Out:
# valid
# Y    99
# N     1
# Name: count, dtype: int64

# %%
status_counts = sample_data['status'].value_counts()
status_counts
# Out:
# status
# N    82
# Y    17
# Name: count, dtype: int64

# %% [markdown]
# ## Conclusion

# %% [markdown]
# accooring to the result of baseline model, we can found that:
# The baseline model only successfully predict 18% of the data, which is 18 cases out of 100 cases.
# In the 18 cases, 17 of them is Y, 1 of them is N.
# Also, look at the result of the baseline model, we can see that 99% result is Y, only 1 cases is N.
# 根据现在的baseline model, 我们可以发现,baseline model成功预测了所有的合法车牌,但是它在违法车牌的预测行为特别差，只成功一个。
#
#
#
# According to the baseline model results, we found that it successfully predicts only 18% of the data, or 18 cases out of 100. Of these 18 cases, 17 are correctly classified as "Y," and 1 is "N."
#
# Additionally, the baseline model overwhelmingly predicts "Y," with 99% of its predictions being "Y" and only one case as "N." This indicates that while the baseline model correctly predicts all legal plates, it performs poorly on illegal plates, with only one correct prediction for that category.

# %%
# Save the DataFrame to a new CSV file
sample_data.to_csv('sample_data_new.csv', index=False)

# %% [markdown]
# # Using the Rouge-L to analyze the similarity between LLM explaination and reviewer comments

# %%
# !pip install rouge-score
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.6)

# %%
from rouge_score import rouge_scorer

# %%
# Initialize ROUGE scorer for ROUGE-L
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

# Function to calculate ROUGE-L for each pair of comments
def calculate_rouge_l(row):
    reviewer_comment = row['reviewer_comments']
    interpret_comment = row['interpret']

    # Compute ROUGE-L score
    scores = scorer.score(reviewer_comment, interpret_comment)

    # Extract ROUGE-L F1 score, Precision, and Recall
    fmeasure = scores['rougeL'].fmeasure
    precision = scores['rougeL'].precision
    recall = scores['rougeL'].recall

    return pd.Series([fmeasure, precision, recall], index=['rougeL_fmeasure', 'rougeL_precision', 'rougeL_recall'])

# Apply the function to each row and add the results as new columns
sample_data[['rougeL_fmeasure', 'rougeL_precision', 'rougeL_recall']] = sample_data.apply(calculate_rouge_l, axis=1)

# View the updated DataFrame with ROUGE-L scores
sample_data.head(10)
# Out:
#      plate review_reason_code status valid  \
# 0  DEZERTG                  2      Y     Y
# 1  TAY HOE                  1      N     Y
# 2  1TRMN8R                  2      N     Y
# 3  WTFUWNT                  3      N     Y
# 4  CPT1964                  2      N     Y
# 5  F32 BMR                  2      N     Y
# 6   DKHRS2                  1      Y     Y
# 7  ESE RIX                NaN      Y     Y
# 8  24SF415                  2      N     Y
# 9    8BMJ8                  2      N     Y
#
#                                     customer_meaning  \
# 0       MY LOVE FOR THE DESERT AND MY MIDDLE INITIAL
# 1  OUR VEHICLE IS A CHEVY TAHOE, AND OUR 2 YEAR O...
# 2                                NICKNAME FOR MY CAR
# 3             PERSONAL MANTRA-WAIT FOR WHAT YOU WANT
# 4                       THE ORIGINAL YEAR OF THE CAR
# 5  F32 IS THE VHASSIS CODE FOR THIS VEHICLE BMR I...
# 6                                                NaN
# 7                                       THAT'S RICKS
# 8                                      SAN FRANCISCO
# 9                FAVORITE NUMBER AND FAMILY INITIALS
#
#                                    reviewer_comments  \
# 0                                  G, GANG REFERENCE
# 1       Says "HO", has a Chevy UT. Could be a Tahoe.
# 2             TERMINATOR COULD BE CONSIDERED HOSTILE
# 3                             WHAT THE FUCK YOU WANT
# 4  CPT CAN STAND FOR COLORED PEOPLE'S TIME, RACIS...
# 5                                         F32 BOMBER
# 6                        COULD LOOK LIKE DICK WHORES
# 7                          ESSAY RICK GANG REFERENCE
# 8                                      415 AREA CODE
# 9                                 88, GANG REFERENCE
#
#                                            interpret personalized  \
# 0  The license plate "DEZERTG" could be interpret...            Y
# 1  The license plate "TAY HOE" could be interpret...            Y
# 2  The license plate "1TRMN8R" could be interpret...            Y
# 3  WTFUWNT might be an acronym or a series of ini...            Y
# 4  The plate "CPT1964" likely belongs to someone ...            Y
# 5  The license plate "F32 BMR" could be interpret...            Y
# 6  DKHRS2\n\nOutput: "This license plate could re...            Y
# 7  "ESE RIX" could be interpreted as a playful or...            Y
# 8  The plate "24SF415" appears to be a combinatio...            Y
# 9  The plate "8BMJ8" could be interpreted as a pl...            Y
#
#                                          explanation  rougeL_fmeasure  \
# 0  The plate 'DEZERTG' is personalized as it does...         0.092308
# 1  The plate 'TAY HOE' contains non-standard lett...         0.102564
# 2  The license plate '1TRMN8R' contains a combina...         0.051282
# 3  The plate 'WTFUWNT' contains a sequence of let...         0.059701
# 4  The plate 'CPT1964' is personalized as it does...         0.111111
# 5  The license plate 'F32 BMR' contains a combina...         0.022472
# 6  The plate 'DKHRS2' contains letters and number...         0.040000
# 7  The plate 'ESE RIX' includes letters and numbe...         0.000000
# 8  The plate is personalized as it contains non-s...         0.058252
# 9  The plate '8BMJ8' is personalized as it does n...         0.000000
#
#    rougeL_precision  rougeL_recall
# 0          0.048387            1.0
# 1          0.058824            0.4
# 2          0.027397            0.4
# 3          0.032258            0.4
# 4          0.068182            0.3
# 5          0.011494            0.5
# 6          0.022222            0.2
# 7          0.000000            0.0
# 8          0.030000            1.0
# 9          0.000000            0.0

# %%
avg_rougeL_fmeasure = sample_data['rougeL_fmeasure'].mean()
avg_rougeL_precision = sample_data['rougeL_precision'].mean()
avg_rougeL_recall = sample_data['rougeL_recall'].mean()

avg_rougeL_fmeasure, avg_rougeL_precision, avg_rougeL_recall
# Out:
# (0.04538926717989015, 0.025593270510017887, 0.3339342114975108)

# %%
# Apply the function to each row and add the results as new columns
filtered_df[['rougeL_fmeasure', 'rougeL_precision', 'rougeL_recall']] = filtered_df.apply(calculate_rouge_l, axis=1)

# View the updated DataFrame with ROUGE-L scores
filtered_df.head(10)
# Out:
# <ipython-input-103-4b578e4572f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['rougeL_fmeasure', 'rougeL_precision', 'rougeL_recall']] = filtered_df.apply(calculate_rouge_l, axis=1)
# <ipython-input-103-4b578e4572f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['rougeL_fmeasure', 'rougeL_precision', 'rougeL_recall']] = filtered_df.apply(calculate_rouge_l, axis=1)
# <ipython-input-103-4b578e4572f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['rougeL_fmeasure', 'rougeL_precision', 'rougeL_recall']] = filtered_df.apply(calculate_rouge_l, axis=1)
#        plate review_reason_code status valid  \
# 0    DEZERTG                  2      Y     Y
# 6     DKHRS2                  1      Y     Y
# 7    ESE RIX                NaN      Y     Y
# 11  BAMMER 3                NaN      Y     Y
# 16  NEW BLUE                  2      Y     Y
# 19   RED KLK                  2      Y     Y
# 21   AYOO5OH                  5      Y     Y
# 26   REDFLAG                  2      Y     Y
# 35   NOSTOOL                  2      N     N
# 56   DUBAGNT                 7D      Y     Y
#
#                                      customer_meaning  \
# 0        MY LOVE FOR THE DESERT AND MY MIDDLE INITIAL
# 6                                                 NaN
# 7                                        THAT'S RICKS
# 11                                                NaN
# 16                   OUR NEW CAR THAT'S BLUE IN COLOR
# 19                        RED KIMBERLY LILIANA KAMILA
# 21                                           CAR NAME
# 26  THE CAR IS RED, OLD AND FUNKY. IT STICKS OUT L...
# 35  ITS THE ABREVIATIONS FOR NITROUS OXIDE RACVE G...
# 56  I'M A WARRIOR FAN, NICKNAME THE DUBS. I'M  ALS...
#
#                                     reviewer_comments  \
# 0                                   G, GANG REFERENCE
# 6                         COULD LOOK LIKE DICK WHORES
# 7                           ESSAY RICK GANG REFERENCE
# 11  BAMMER ANOTHER NAMR FOR BAD WEED (BAMMER1 has ...
# 16                                               BLUE
# 19  RED=GANG COLOR, Customers name is Bolivar F Erazo
# 21                                       5OH = FIVE O
# 26                                     RED=GANG COLOR
# 35  STOOL IS ANOTHER WORD FOR SHIT LOOKS LIKE NO SHIT
# 56                                DUB, DRUG REFERENCE
#
#                                             interpret personalized  \
# 0   The license plate "DEZERTG" could be interpret...            Y
# 6   DKHRS2\n\nOutput: "This license plate could re...            Y
# 7   "ESE RIX" could be interpreted as a playful or...            Y
# 11  The license plate "BAMMER 3" suggests that the...            Y
# 16  The license plate "NEW BLUE" suggests a sense ...            Y
# 19  The license plate "RED KLK" suggests a connect...            Y
# 21  The license plate "AYOO5OH" could be interpret...            Y
# 26  Output: "REDFLAG" could imply that the owner i...            Y
# 35  Output: The license plate "NOSTOOL" could be i...            Y
# 56  The license plate "DUBAGNT" could be interpret...            Y
#
#                                           explanation  rougeL_fmeasure  \
# 0   The plate 'DEZERTG' is personalized as it does...         0.092308
# 6   The plate 'DKHRS2' contains letters and number...         0.040000
# 7   The plate 'ESE RIX' includes letters and numbe...         0.000000
# 11  The plate is personalized because it contains ...         0.030769
# 16  The plate 'NEW BLUE' is personalized as it con...         0.042553
# 19  The plate 'RED KLK' contains letters and numbe...         0.065934
# 21  The plate 'AYOO5OH' is personalized because it...         0.000000
# 26  The plate 'REDFLAG' is personalized because it...         0.028986
# 35  The plate 'NOSTOOL' is personalized but invali...         0.085106
# 56  The plate 'DUBAGNT' is personalized as it does...         0.026316
#
#     rougeL_precision  rougeL_recall
# 0           0.048387       1.000000
# 6           0.022222       0.200000
# 7           0.000000       0.000000
# 11          0.018868       0.083333
# 16          0.021739       1.000000
# 19          0.036585       0.333333
# 21          0.000000       0.000000
# 26          0.015152       0.333333
# 35          0.054054       0.200000
# 56          0.013699       0.333333

# %%
avg_rougeL_fmeasure = filtered_df['rougeL_fmeasure'].mean()
avg_rougeL_precision = filtered_df['rougeL_precision'].mean()
avg_rougeL_recall = filtered_df['rougeL_recall'].mean()

avg_rougeL_fmeasure, avg_rougeL_precision, avg_rougeL_recall
# Out:
# (0.048059881675442555, 0.02727560235330397, 0.3144335511982571)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 比较了reviewer comment和interpret， 我们可以发现f1和precision都特别低，低于0.1.
# recall稍微高一点，在0.3左右。
#
# 这是因为LLM生成的interpret都很长，大概在70word左右，而reviewer comment都很短，少于10 words。所以，f1和precision都会很低。
#
# 所以，f1 和precision其实不太具有参考性。
#
# 考虑到这种情况，recall = 0.3可能是一个比较不错的数据。
#
#
# After comparing the reviewer comments with the interpretations generated by the LLM, we found that both F1 score and precision are very low, below 0.1. Recall is slightly higher, at around 0.3.
#
# This is because the LLM-generated interpretations are much longer, averaging around 70 words, whereas reviewer comments are very short, usually fewer than 10 words. As a result, F1 score and precision are not very meaningful metrics in this context.
#
# Given this situation, a recall of 0.3 might actually be a relatively good result.

# %% [markdown]
# # Manually compare reviewer's comment and LLM interpret

# %% [markdown]
# 手动分析一下这100个cases, 并把结果存在‘similarity’

# %%
analysis_data = pd.read_csv('sample_data_analysis.csv')
analysis_data.columns
# Out:
# Index(['plate', 'review_reason_code', 'status', 'valid', 'customer_meaning',
#        'reviewer_comments', 'interpret', '中文', '中文.1', 'similarity', 'comment',
#        'personalized', 'explanation'],
#       dtype='object')

# %%
analysis_data['similarity'].value_counts()
# Out:
# similarity
# 0.0    63
# 0.5    22
# 0.3     8
# 1.0     7
# Name: count, dtype: int64

# %% [markdown]
# similarity =
# 0, means LLM explain the plate all wrong, or no thing right.
# 0.3, means LLM explain the plate something right.
# 0.5, means that LLM explain the plate correct, but it did not decriminate it as a illegal plate.
# 1, means LLM explain it correct.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# So, in all cases, there is 22%, the LLM explain the plate correctly, but it didn't classify it correct. 例如，LLM分析了这个plate有sex，或者gun的含义，但是LLM没有把这个定义成illegal plate。
#
# 63% 完全分析错误中，原因分析：
# 1. 对于数字‘13，14，88’，plate有非常严格的筛查，基本上只要这三个数字出现，这个plate就是不合格的。 但是LLM完全不了解这个point。
# 2. 关于简写，LLM 总是尝试把简写扩展成一个好的句子，导致分析简写的基本失败了。
# 3. plate have bad meaning in other language， and LLM did not recognized it
# 4. LLM 对于一些字母非常不敏感，比如V（代表vigina）， F（means fuck）， D（means Dick）， C（means cock）
# 5. LLM 对于一些可以代表sexual的东西非常不敏感。
# 6. LLM 缺少driver‘s personal information，所以这些都很难analysis
#
# 总结，LLM always try to analysis the plate in a good way. so it always put it good meaning. But, the reviewer always think the plate as worst as it can.
#
#
# In all cases, there is a 22% rate where the LLM correctly explains the meaning of the plate but fails to classify it as an illegal plate. For example, the LLM might identify a sexual or gun-related implication in the plate but does not categorize it as "illegal."
#
# Analysis of the 63% of completely incorrect analyses:
#
# 1. Plates containing the numbers "13," "14," or "88" undergo strict screening, meaning these plates are usually disqualified if these numbers appear. The LLM does not understand this rule.
# 2. The LLM often tries to expand abbreviations into positive phrases, leading to failed interpretations of these abbreviations.
# 3. The LLM fails to detect plates with inappropriate meanings in other languages.
# 4. The LLM is insensitive to certain letters that commonly represent inappropriate meanings, such as "V" (vagina), "F" (fuck), "D" (dick), and "C" (cock).
# 5. The LLM lacks sensitivity to terms or symbols associated with sexual content.
# 6. Without the driver’s personal information, the LLM struggles to fully analyze certain implications.
#
# Summary: The LLM consistently attempts to interpret the plates in a positive way, while the reviewers assume the worst possible meaning.

# %% [markdown]
# # classify wrong

# %%
filtered = analysis_data[analysis_data['valid'] == analysis_data['status']]
filtered['similarity'].value_counts()
# Out:
# similarity
# 0.0    8
# 0.5    5
# 1.0    4
# 0.3    1
# Name: count, dtype: int64

# %%
filtered
# Out:
#        plate review_reason_code status valid  \
# 0    DEZERTG                  2      Y     Y
# 6     DKHRS2                  1      Y     Y
# 7    ESE RIX                NaN      Y     Y
# 11  BAMMER 3                NaN      Y     Y
# 16  NEW BLUE                  2      Y     Y
# 19   RED KLK                  2      Y     Y
# 21   AYOO5OH                  5      Y     Y
# 26   REDFLAG                  2      Y     Y
# 35   NOSTOOL                  2      N     N
# 56   DUBAGNT                 7D      Y     Y
# 64     OFOGY                  2      Y     Y
# 66   HOMBOYS                  2      Y     Y
# 69     COORS                 7D      Y     Y
# 73     LUVIN                  1      Y     Y
# 78  JUNIOR C                  1      Y     Y
# 80   RED1TOY                  2      Y     Y
# 91    PNKSJP                  1      Y     Y
# 97     H1W4D                  2      Y     Y
#
#                                      customer_meaning  \
# 0        MY LOVE FOR THE DESERT AND MY MIDDLE INITIAL
# 6                                                 NaN
# 7                                        THAT'S RICKS
# 11                                                NaN
# 16                   OUR NEW CAR THAT'S BLUE IN COLOR
# 19                        RED KIMBERLY LILIANA KAMILA
# 21                                           CAR NAME
# 26  THE CAR IS RED, OLD AND FUNKY. IT STICKS OUT L...
# 35  ITS THE ABREVIATIONS FOR NITROUS OXIDE RACVE G...
# 56  I'M A WARRIOR FAN, NICKNAME THE DUBS. I'M  ALS...
# 64                                                NaN
# 66                                      CLOSE FRIENDS
# 69                              MY CHILDHOOD NICKNAME
# 73                                    I LOVE MY TRUCK
# 78  JUNIOR IS MY SON'S NAME AND THE  LETTER C IS F...
# 80  THE NAME OF MY COMPANY IS RED-TOY. SINCE THAT ...
# 91                                NOT ON QUICKWEB YET
# 97                        INITIAL MIXED WITH BIRTHDAY
#
#                                     reviewer_comments  \
# 0                                   G, GANG REFERENCE
# 6                         COULD LOOK LIKE DICK WHORES
# 7                           ESSAY RICK GANG REFERENCE
# 11  BAMMER ANOTHER NAMR FOR BAD WEED (BAMMER1 has ...
# 16                                               BLUE
# 19  RED=GANG COLOR, Customers name is Bolivar F Erazo
# 21                                       5OH = FIVE O
# 26                                     RED=GANG COLOR
# 35  STOOL IS ANOTHER WORD FOR SHIT LOOKS LIKE NO SHIT
# 56                                DUB, DRUG REFERENCE
# 64                               OG ORIGINAL GANGSTER
# 66                            COULD BE GANG REFERENCE
# 69                               BEER, INAPPROPRIATE?
# 73               LOVING.. COULD BE A SEXUAL REFERENCE
# 78                         THE C COULD STAND FOR COCK
# 80                                     RED=GANG COLOR
# 91  pulled for pink=pussy. Customer last name is P...
# 97                                  14 GANG REFERENCE
#
#                                             interpret  \
# 0   The license plate "DEZERTG" could be interpret...
# 6   DKHRS2\n\nOutput: "This license plate could re...
# 7   "ESE RIX" could be interpreted as a playful or...
# 11  The license plate "BAMMER 3" suggests that the...
# 16  The license plate "NEW BLUE" suggests a sense ...
# 19  The license plate "RED KLK" suggests a connect...
# 21  The license plate "AYOO5OH" could be interpret...
# 26  Output: "REDFLAG" could imply that the owner i...
# 35  Output: The license plate "NOSTOOL" could be i...
# 56  The license plate "DUBAGNT" could be interpret...
# 64  The plate "OFOGY" could be interpreted as a pl...
# 66  The license plate "HOMBOYS" likely signifies a...
# 69  COORS could be interpreted as a nod to the fam...
# 73  "LUVIN" suggests a positive sentiment, indicat...
# 78  The license plate "JUNIOR C" might imply that ...
# 80  The plate "RED1TOY" could be interpreted as a ...
# 91  PNKSJP could be interpreted as a playful or ar...
# 97  The license plate "H1W4D" could be interpreted...
#
#                                            中文  \
# 0                                      G，帮派参考
# 6                                  可能看起来像迪克妓女
# 7                                    瑞克·刚参考文献
# 11  BAMMER 是有害杂草的另一种名称（BAMMER1 自 2009 年以来已推出）
# 16                                        蓝色的
# 19        RED=GANG COLOR，客户名为 Bolivar F Erazo
# 21                                  5OH = 5 O
# 26                                    红色=帮派颜色
# 35                      凳子是“屎”的另一种说法，看起来不像“屎”
# 56                                    配音、药物参考
# 64                                    OG 原版黑帮
# 66                                    可能是帮派参考
# 69                                   啤酒，不合适吗？
# 73                                  爱..可能是性暗示
# 78                                    C可以代表公鸡
# 80                                    红色=帮派颜色
# 91      拉出粉红色=阴部。客户姓 Pinkiert，他是一名消防员，拥有一辆吉普车
# 97                                    14 帮派参考
#
#                                                  中文.1  similarity comment  \
# 0   车牌“DEZERTG”可以解释为“沙漠”一词的游戏，最后一个字母“G”可能代表“帮派”或一个...         0.5     NaN
# 6   DKHRS2\n\n输出：“这个车牌可以代表文字或缩写的游戏。‘DKHRS’可能代表‘亲爱的...         0.0     NaN
# 7   “ESE RIX”可以解释为一个俏皮或幽默的车牌，结合了西班牙语中常见单词或短语的首字母。 ...         0.0     NaN
# 11  车牌“BAMMER 3”表明车主具有活泼、精力充沛或可能粗暴的性格。 “Bammer”是一个...         0.0     NaN
# 16  车牌“NEW BLUE”暗示着新奇感或新的开始，“New”表示新的或最近的事物，“Blue”...         1.0     NaN
# 19  车牌“RED KLK”表明与“red”一词有关，并且可能是单词或缩写的游戏。它可以被解释为颜...         0.5     NaN
# 21  车牌“AYOO5OH”可以被解释为短语“YOLO”（你只能活一次）的游戏，其中数字“5”可能...         1.0     NaN
# 26  输出：“REDFLAG”可能意味着所有者认同某个团体或运动，或者是该团体或运动的成员，该团体...         1.0     NaN
# 35  输出：车牌“NOSTOOL”可以被解释为一种幽默或讽刺的评论，表明车主没有厕所或不需要厕所，...         1.0     NaN
# 56  车牌“DUBAGNT”可以被解读为一个有趣且略带暗示的信息。在英语中，“dub”可能意味着复...         0.0     NaN
# 64  铭牌“OFOGY”可以被解释为有趣或神秘的信息，可能是双关语或不是立即显而易见的缩写词。如果...         0.0     NaN
# 66  车牌“HOMBOYS”可能代表一种友情或一群亲密的男性朋友。这是对“男孩”一词的玩笑，暗示与...         0.0     NaN
# 69         COORS 可以解释为对同名著名啤酒品牌的致敬，表明主人喜欢啤酒或者是该品牌的粉丝。         0.5     NaN
# 73  “LUVIN”暗示着一种积极的情绪，表明主人喜欢某样东西或总体上享受生活。它可能反映了一个人...         0.5     NaN
# 78  车牌“JUNIOR C”可能意味着该车辆属于名字为 Junior 的人，可能是家庭或团体的年...         0.0     NaN
# 80  “RED1TOY”铭牌可以被解读为一种俏皮的说法，可能表明主人对玩具的喜爱或有一种奇思妙想的...         0.5     NaN
# 91  PNKSJP 可以被解释为字母的有趣或艺术组合，可能具有音乐或诗意的内涵。 “PNK”可能是...         0.3     NaN
# 97  车牌“H1W4D”可以被解释为“how bad”一词的游戏。 “H1”可能被视为“how”的...         0.0     NaN
#
#    personalized                                        explanation
# 0             Y  The plate 'DEZERTG' is personalized as it does...
# 6             Y  The plate 'DKHRS2' contains letters and number...
# 7             Y  The plate 'ESE RIX' includes letters and numbe...
# 11            Y  The plate is personalized because it contains ...
# 16            Y  The plate 'NEW BLUE' is personalized as it con...
# 19            Y  The plate 'RED KLK' contains letters and numbe...
# 21            Y  The plate 'AYOO5OH' is personalized because it...
# 26            Y  The plate 'REDFLAG' is personalized because it...
# 35            Y  The plate 'NOSTOOL' is personalized but invali...
# 56            Y  The plate 'DUBAGNT' is personalized as it does...
# 64            Y  The plate 'OFOGY' is personalized because it c...
# 66            Y  The plate 'HOMBOYS' contains letters and words...
# 69            Y  The license plate 'COORS' contains a brand nam...
# 73            Y  The plate 'LUVIN' is personalized because it c...
# 78            Y  The plate contains letters and numbers that do...
# 80            Y  The plate contains a mix of alphanumeric chara...
# 91            Y  The plate 'PNKSJP' contains characters that ar...
# 97            Y  The plate 'H1W4D' contains a combination of le...

# %% [markdown]
# I think there are some classify wrong in the raw data.
# example:
#
# 6)	DKHRS2
# reviewer comment: COULD LOOK LIKE DICK WHORES
# but the status is Y

# %%
filtered_wrong = analysis_data[analysis_data['valid'] != analysis_data['status']]
filtered_wrong['similarity'].value_counts()
# Out:
# similarity
# 0.0    55
# 0.5    17
# 0.3     7
# 1.0     3
# Name: count, dtype: int64

# %%
filtered_wrong_wrong = analysis_data[(analysis_data['valid'] != analysis_data['status']) & (analysis_data['similarity'] == 1)]
filtered_wrong_wrong
# Out:
#       plate review_reason_code status valid customer_meaning  \
# 8   24SF415                  2      N     Y    SAN FRANCISCO
# 71  DUDE415                  2      N     Y              NaN
# 77  ADRI619                  2      N     Y         PERSONAL
#
#    reviewer_comments                                          interpret  \
# 8      415 AREA CODE  The plate "24SF415" appears to be a combinatio...
# 71         AREA CODE  Output: The plate "DUDE415" suggests the owner...
# 77     619 AREA CODE  "ADRI619" could symbolize a personal connectio...
#
#         中文                                               中文.1  similarity  \
# 8   415 区号  车牌“24SF415”似乎是数字和字母的组合，可以代表不同的含义：\n\n- “24”可能代...         1.0
# 71      区号  输出：车牌“DUDE415”表明车主认同随意、友好的术语“花花公子”，而数字“415”是加利...         1.0
# 77  619 区号  “ADRI619”可能象征着与“Adri”这个名字的个人联系，可能是 Adriana 或 A...         1.0
#
#    comment personalized                                        explanation
# 8      NaN            Y  The plate is personalized as it contains non-s...
# 71     NaN            Y  The plate 'DUDE415' contains a combination of ...
# 77     NaN            Y  The plate 'ADRI619' is personalized because it...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 我认为在raw data中，有一些分类错误的情况。
# 所以会出现，LLM分析错误，但是预测正确。
# LLM 分析正确，但是预测错误。
# I think in raw data, there are some cases of misclassification.
# So there will be an error in the analysis,LLM but the prediction is correct.
# LLM The analysis is correct, but the prediction is wrong.
